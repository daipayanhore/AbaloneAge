# %%
#Loading important packages
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Loading csv file
data= pd.read_csv("abalone.data.csv")
data
# Out:
#      Sex  Length  Diameter  Height  Whole weightShucked weight  \
# 0      M   0.455     0.365   0.095                      0.5140
# 1      M   0.350     0.265   0.090                      0.2255
# 2      F   0.530     0.420   0.135                      0.6770
# 3      M   0.440     0.365   0.125                      0.5160
# 4      I   0.330     0.255   0.080                      0.2050
# ...   ..     ...       ...     ...                         ...
# 4172   F   0.565     0.450   0.165                      0.8870
# 4173   M   0.590     0.440   0.135                      0.9660
# 4174   M   0.600     0.475   0.205                      1.1760
# 4175   F   0.625     0.485   0.150                      1.0945
# 4176   M   0.710     0.555   0.195                      1.9485
#
#       Viscera weight  Shell weight   Rings  Age
# 0             0.2245        0.1010  0.1500   15
# 1             0.0995        0.0485  0.0700    7
# 2             0.2565        0.1415  0.2100    9
# ...

# %%
#Checking the data graphically
x= data['Rings']
y= data['Age']
plt.scatter(x,y)
plt.xlabel("Rings")
plt.ylabel("Age")
plt.title("Age v. Rings")
plt.show()

# %%
#Creating a dataframe with just desired attributes
df= data[['Rings', 'Age']]
df.columns = ['Rings', 'Age']
df
# Out:
#        Rings  Age
# 0     0.1500   15
# 1     0.0700    7
# 2     0.2100    9
# 3     0.1550   10
# 4     0.0550    7
# ...      ...  ...
# 4172  0.2490   11
# 4173  0.2605   10
# 4174  0.3080    9
# 4175  0.2960   10
# 4176  0.4950   12
#
# [4177 rows x 2 columns]

# %%
df.info()   #Checking the information of selected attributes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rings   4177 non-null   float64
#  1   Age     4177 non-null   int64
# dtypes: float64(1), int64(1)
# memory usage: 65.4 KB

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression as lr

x= np.array(x).reshape(-1,1)
y= np.array(y).reshape(-1,1)
x_train, x_test, y_train, y_test = tts(x,y,test_size = 0.20, random_state= 0)
reg= lr()
reg.fit(x_train, y_train)
y_pred= reg.predict(x_test)
y_pred

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.4041925647535849

# %%
plt.scatter(x,y,s= 5, c= 'green')  #s for size, c for color
plt.plot(x_test, y_pred,c= 'red', linewidth= 2)
plt.xlabel("Number of Rings", color= "blue")
plt.ylabel("Age", color ="blue")
plt.title("Linear Regression Model version UNO", size= 20)
plt.show()
